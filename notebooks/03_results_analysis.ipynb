# %% [markdown]
# ## Load LOOCV results

# %%
import pandas as pd
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
sys.path.append(str(PROJECT_ROOT))
from src.config import LOOCV_METRICS_CSV, LOOCV_PREDS_CSV

metrics = pd.read_csv(LOOCV_METRICS_CSV); metrics
# Out:
#                 model  accuracy        f1  roc_auc
# 0  LogisticRegression       0.6  0.500000     0.62
# 1            Majority       0.5  0.000000     0.50
# 2        DecisionTree       0.5  0.545455     0.50
# 3        RandomForest       0.5  0.444444     0.54

# %% [markdown]
# ## Per-PDB prediction table

# %%
preds = pd.read_csv(LOOCV_PREDS_CSV)
preds.pivot(index="pdb_id", columns="model",
            values="correct").style.background_gradient(cmap="RdYlGn")
# Out:
# <style type="text/css">
# #T_93b64_row0_col0, #T_93b64_row0_col1, #T_93b64_row0_col2, #T_93b64_row0_col3, #T_93b64_row1_col1, #T_93b64_row1_col2, #T_93b64_row1_col3, #T_93b64_row2_col0, #T_93b64_row2_col1, #T_93b64_row2_col3, #T_93b64_row4_col2, #T_93b64_row5_col1, #T_93b64_row5_col2, #T_93b64_row6_col0, #T_93b64_row6_col3, #T_93b64_row8_col0, #T_93b64_row8_col2, #T_93b64_row8_col3, #T_93b64_row9_col0 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_93b64_row1_col0, #T_93b64_row2_col2, #T_93b64_row3_col0, #T_93b64_row3_col1, #T_93b64_row3_col2, #T_93b64_row3_col3, #T_93b64_row4_col0, #T_93b64_row4_col1, #T_93b64_row4_col3, #T_93b64_row5_col0, #T_93b64_row5_col3, #T_93b64_row6_col1, #T_93b64_row6_col2, #T_93b64_row7_col0, #T_93b64_row7_col1, #T_93b64_row7_col2, #T_93b64_row7_col3, #T_93b64_row8_col1, #T_93b64_row9_col1, #T_93b64_row9_col2, #T_93b64_row9_col3 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_93b64">
#   <thead>
#     <tr>
#       <th class="index_name level0" >model</th>
#       <th id="T_93b64_level0_col0" class="col_heading level0 col0" >DecisionTree</th>
#       <th id="T_93b64_level0_col1" class="col_heading level0 col1" >LogisticRegression</th>
#       <th id="T_93b64_level0_col2" class="col_heading level0 col2" >Majority</th>
#       <th id="T_93b64_level0_col3" class="col_heading level0 col3" >RandomForest</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >pdb_id</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_93b64_level0_row0" class="row_heading level0 row0" >5O3L</th>
#       <td id="T_93b64_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_93b64_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_93b64_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_93b64_row0_col3" class="data row0 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_93b64_level0_row1" class="row_heading level0 row1" >6XYO</th>
#       <td id="T_93b64_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_93b64_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_93b64_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_93b64_row1_col3" class="data row1 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_93b64_level0_row2" class="row_heading level0 row2" >7LNA</th>
#       <td id="T_93b64_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_93b64_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_93b64_row2_col2" class="data row2 col2" >1</td>
#       <td id="T_93b64_row2_col3" class="data row2 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_93b64_level0_row3" class="row_heading level0 row3" >7P6A</th>
#       <td id="T_93b64_row3_col0" class="data row3 col0" >1</td>
#       <td id="T_93b64_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_93b64_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_93b64_row3_col3" class="data row3 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_93b64_level0_row4" class="row_heading level0 row4" >7YAT</th>
#       <td id="T_93b64_row4_col0" class="data row4 col0" >1</td>
#       <td id="T_93b64_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_93b64_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_93b64_row4_col3" class="data row4 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_93b64_level0_row5" class="row_heading level0 row5" >7ZJ2</th>
#       <td id="T_93b64_row5_col0" class="data row5 col0" >1</td>
#       <td id="T_93b64_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_93b64_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_93b64_row5_col3" class="data row5 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_93b64_level0_row6" class="row_heading level0 row6" >9GKF</th>
#       <td id="T_93b64_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_93b64_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_93b64_row6_col2" class="data row6 col2" >1</td>
#       <td id="T_93b64_row6_col3" class="data row6 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_93b64_level0_row7" class="row_heading level0 row7" >9IAH</th>
#       <td id="T_93b64_row7_col0" class="data row7 col0" >1</td>
#       <td id="T_93b64_row7_col1" class="data row7 col1" >1</td>
#       <td id="T_93b64_row7_col2" class="data row7 col2" >1</td>
#       <td id="T_93b64_row7_col3" class="data row7 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_93b64_level0_row8" class="row_heading level0 row8" >9JHG</th>
#       <td id="T_93b64_row8_col0" class="data row8 col0" >0</td>
#       <td id="T_93b64_row8_col1" class="data row8 col1" >1</td>
#       <td id="T_93b64_row8_col2" class="data row8 col2" >0</td>
#       <td id="T_93b64_row8_col3" class="data row8 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_93b64_level0_row9" class="row_heading level0 row9" >9KAL</th>
#       <td id="T_93b64_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_93b64_row9_col1" class="data row9 col1" >1</td>
#       <td id="T_93b64_row9_col2" class="data row9 col2" >1</td>
#       <td id="T_93b64_row9_col3" class="data row9 col3" >1</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Inspect the misses for biological discussion

# %%
preds[preds["correct"] == 0].merge(
    pd.read_csv("../data/labels.csv"), on="pdb_id"
)[["model", "pdb_id", "protein", "morphology", "y_pred", "proba_multi"]]
# Out:
#                  model pdb_id             protein morphology  y_pred  \
# 0             Majority   9JHG  Beta-lactoglobulin      multi       0
# 1             Majority   7YAT               Prion      multi       0
# 2             Majority   7ZJ2             hnRNPA1      multi       0
# 3             Majority   5O3L                 Tau      multi       0
# 4             Majority   6XYO     Alpha-synuclein      multi       0
# 5   LogisticRegression   7LNA               Prion     single       1
# 6   LogisticRegression   7ZJ2             hnRNPA1      multi       0
# 7   LogisticRegression   5O3L                 Tau      multi       0
# 8   LogisticRegression   6XYO     Alpha-synuclein      multi       0
# 9         DecisionTree   9JHG  Beta-lactoglobulin      multi       0
# 10        DecisionTree   7LNA               Prion     single       1
# 11        DecisionTree   9GKF             hnRNPA1     single       1
# 12        DecisionTree   5O3L                 Tau      multi       0
# 13        DecisionTree   9KAL     Alpha-synuclein     single       1
# 14        RandomForest   9JHG  Beta-lactoglobulin      multi       0
# 15        RandomForest   7LNA               Prion     single       1
# 16        RandomForest   9GKF             hnRNPA1     single       1
# 17        RandomForest   5O3L                 Tau      multi       0
# 18        RandomForest   6XYO     Alpha-synuclein      multi       0
#
#     proba_multi
# 0      0.000000
# 1      0.000000
# 2      0.000000
# 3      0.000000
# 4      0.000000
# 5      0.879199
# 6      0.297312
# 7      0.448937
# 8      0.020315
# 9      0.000000
# 10     1.000000
# 11     1.000000
# 12     0.000000
# 13     1.000000
# 14     0.450167
# 15     0.512750
# 16     0.530000
# 17     0.427250
# 18     0.392083
